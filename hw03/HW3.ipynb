# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gc
import os
import json
import math
import sys
import time

import numpy as np
import tensorflow as tf
import scipy.sparse as sp
import faiss
import implicit

import data
import modeling

# %% [markdown]
# # 1. Find the Dataset

# %% [markdown]
# I use one of the datasets from https://arxiv.org/pdf/2005.09347.pdf. It is the Amazon Review Data (2018). The dataset is described:
#
# """This Dataset is an updated version of the Amazon review dataset released in 2014. As in the previous version, this dataset includes reviews (ratings, text, helpfulness votes), product metadata (descriptions, category information, price, brand, and image features), and links (also viewed/also bought graphs)."""
#
# I use the data for the Books category, the category where it has all started.
#
# I pick the dataset based on the following pros:
# - The dataset clearly presents the sequential interaction of users with the products.
# - The dataset contains real-world interactions for the largest e-commerce store in the world.
# - It is complex as there are hundreds of thousands of users and items (the exact number of users is 482934, the exact number of items is 367964.

# %%
train_name = "train"
valid_name = "valid"
test_name = "test"

# %%
data_path = "/data/msazanovich/recommender-systems/data/"
batch_size = 128
maxlen = 20

# %%
dataset = "book"
train_file = os.path.join(data_path, "book_data", f"{dataset}_train.txt")
valid_file = os.path.join(data_path, "book_data", f"{dataset}_valid.txt")
test_file = os.path.join(data_path, "book_data", f"{dataset}_test.txt")

# %%
def summarize_data_split(data_iter, split):
  print(f'{split} users:', len(data_iter.users))
  print(f'{split} items:', len(data_iter.items))
  interactions = 0
  for user, items in data_iter.graph.items():
    interactions += len(items)
  print(f'{split} interactions:', interactions)

# %%
train_data = data.DataIterator(train_file, batch_size, maxlen, is_train=True)

# %%
user_count = max(train_data.users) + 1
item_count = max(train_data.items) + 1

# %%
summarize_data_split(train_data, 'Train')
# Out:
# Train users: 482934
# Train items: 367964
# Train interactions: 7145481

# %%
valid_data = data.DataIterator(valid_file, batch_size, maxlen, is_train=False)

# %%
summarize_data_split(valid_data, 'Valid')
# Out:
# Valid users: 60367
# Valid items: 249664
# Valid interactions: 874813

# %%
test_data = data.DataIterator(test_file, batch_size, maxlen, is_train=False)

# %%
summarize_data_split(test_data, 'Test')
# Out:
# Test users: 60367
# Test items: 249724
# Test interactions: 877747

# %%
item_asin_to_id = {}
with open(os.path.join(data_path, "book_data", "book_item_map.txt"), "r") as f:
  for line in f:
    item_asin, item_id = line.strip().split(',')
    item_asin_to_id[item_asin] = int(item_id)

# %%
item_id_to_title = {}
with open(os.path.join(data_path, "meta_Books.json"), "r") as f:
  for line in f:
    r = eval(line.strip())
    item_asin = r["asin"]
    if item_asin in item_asin_to_id:
      item_id = item_asin_to_id[item_asin]
      item_title = r.get("title", "N/A")
      item_id_to_title[item_id] = item_title

# %% [markdown]
# # 1.5 Setup the Evaluation method

# %%
def build_item_index(item_embs):
  res = faiss.StandardGpuResources()
  flat_config = faiss.GpuIndexFlatConfig()
  flat_config.device = 0
  gpu_index = faiss.GpuIndexFlatIP(res, embedding_dim, flat_config)
  gpu_index.add(item_embs)
  return gpu_index


def eval_model_on(data_iter, item_embs_fn, user_embs_fn, top_n=50):
  item_embs = item_embs_fn()
  gpu_index = build_item_index(item_embs)
  
  start_time = time.time()

  total = 0
  recall_sum = 0.0
  ndcg_sum = 0.0
  hitrate_sum = 0.0
  for src, tgt in data_iter:
    (user_id_list, item_id_list), (hist_item_list, hist_mask_list) = src, tgt
    user_embs = user_embs_fn(hist_item_list, hist_mask_list)
    D, I = gpu_index.search(user_embs, top_n)
    for i, relevant_ids in enumerate(item_id_list):
      recall = 0
      dcg = 0.0
      for j in range(top_n):
        if I[i][j] in relevant_ids:
          recall += 1
          dcg += 1.0 / math.log(j+2, 2)
      idcg = 0.0
      for j in range(min(len(relevant_ids), top_n)):
        idcg += 1.0 / math.log(j+2, 2)

      total += 1
      recall_sum += recall * 1.0 / len(relevant_ids)
      ndcg_sum += dcg / idcg
      hitrate_sum += 1.0 if recall > 0 else 0.0

  recall = recall_sum / total
  ndcg = ndcg_sum / total
  hitrate = hitrate_sum / total
  return {'users': total, 'recall': recall, 'ndcg': ndcg, 'hitrate': hitrate}

# %%
model_metrics = {}

# %%
eval_item_id = list(range(1, 10))

# %%
def eval_similar_items(item_embs_fn):
  item_embs = item_embs_fn()
  gpu_index = build_item_index(item_embs)

  eval_item_embs = [item_embs[item_id] for item_id in eval_item_id]
  D, I = gpu_index.search(np.array(eval_item_embs), 10)
  for item_id, ii, dd in zip(eval_item_id, D, I):
    print("Item title:", item_id_to_title[item_id])
    print("Similar items are:")
    for d, i in zip(ii, dd):
      print(d, item_id_to_title[i])
    print()

# %%
(_, _), (eval_hist_item_list, eval_hist_mask_list) = next(test_data)
eval_hist_item_list = eval_hist_item_list[:10]
eval_hist_mask_list = eval_hist_mask_list[:10]
test_data.index = 0

# %%
def eval_user_recommendations(item_embs_fn, user_embs_fn):
  item_embs = item_embs_fn()
  gpu_index = build_item_index(item_embs)
  
  user_embs = user_embs_fn(eval_hist_item_list, eval_hist_mask_list)
  D, I = gpu_index.search(user_embs, 10)
  for hist_item_list, hist_mask_list, dd, ii in zip(eval_hist_item_list, eval_hist_mask_list, D, I):
    print('For the user with history:')
    for item, mask in zip(hist_item_list, hist_mask_list):
      if mask == 0.0:
        break
      print(item_id_to_title[item])
    print("Recommendations are are:")
    for d, i in zip(dd, ii):
      print(d, item_id_to_title[i])
    print()

# %% [markdown]
# # 2. Collaborative Filtering

# %% [markdown]
# I choose the Bayesian Personalized Ranking (BPR) for the collaborative filtering model.

# %%
users_coo = []
items_coo = []
for user, items in train_data.graph.items():
  users_coo.extend([user] * len(items))
  items_coo.extend(items)
print(len(users_coo))
print(len(items_coo))

user_item = sp.coo_matrix((np.ones_like(users_coo), (users_coo, items_coo)))
user_item_t_csr = user_item.T.tocsr()

del users_coo, items_coo
gc.collect()
# Out:
# 7145481
# 7145481
# 0

# %%
embedding_dim = 64
bpr_iterations = 1000
model_bpr = (
  implicit.bpr.BayesianPersonalizedRanking(
    factors=embedding_dim,
    iterations=bpr_iterations,
    use_gpu=False))

# %%
model_bpr.fit(user_item_t_csr)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
bpr_item_embs = model_bpr.item_factors[:, :-1]
bpr_item_embs = np.ascontiguousarray(bpr_item_embs)
bpr_item_embs.shape
# Out:
# (367983, 64)

# %%
def bpr_item_embs_fn():
  return bpr_item_embs

# %%
def bpr_user_embs_fn(hist_item_list, hist_mask_list):
  hist_item_arr = np.array(hist_item_list, dtype=np.int32)
  hist_mask_arr = np.array(hist_mask_list, dtype=np.float32)
  n, m = hist_mask_arr.shape
  hist_item_embs = bpr_item_embs[hist_item_arr.flatten()].reshape((n, m, -1))
  hist_item_embs = hist_item_embs * np.expand_dims(hist_mask_arr, axis=-1)
  user_embs = np.sum(hist_item_embs, axis=1) / np.sum(hist_mask_arr, axis=1, keepdims=True)
  return user_embs

# %% [markdown]
# ## CF Quantitative evaluation

# %%
test_metrics = eval_model_on(
    data_iter=test_data,
    item_embs_fn=bpr_item_embs_fn,
    user_embs_fn=bpr_user_embs_fn)
print(f"test metrics: {test_metrics}")
# Out:
# test metrics: {'users': 60367, 'recall': 0.0793839708971102, 'ndcg': 0.030340466471052048, 'hitrate': 0.157287922209154}

# %%
model_metrics["BPR"] = test_metrics

# %% [markdown]
# ## CF Qualitative evaluation

# %%
eval_similar_items(bpr_item_embs_fn)
# Out:
# Item title: Gone Girl
# Similar items are:
# 4.8599844 Gone Girl
# 3.9932723 Sharp Objects: A Novel
# 3.885926 Dark Places: A Novel
# 3.6470726 Defending Jacob: A Novel
# 3.6303177 The Silent Wife: A Novel
# 3.4425368 The Dinner
# 3.3613777 The Husband's Secret
# 3.2325141 The Light Between Oceans
# 3.223132 Tell the Wolves I'm Home: A Novel
# 3.1953988 What We Leave Behind
#
# Item title: The Hunger Games (The Hunger Games, Book 1)
# Similar items are:
# 5.520539 The Hunger Games (The Hunger Games, Book 1)
# 5.338859 Mockingjay (The Final Book of The Hunger Games)
# 5.1231794 Catching Fire (The Hunger Games, Book 2)
# 5.0399427 Catching Fire (The Hunger Games, Book 2)
# 3.5671346 Dream Cat
# 3.2384362 Catching Fire
# 3.1875901 The Hunger Games: Official Illustrated Movie Companion
# 3.1383018 Class A (CHERUB #2) (Bk. 2)
# 3.1333385 Katniss the Cattail: An Unauthorized Guide to Names and Symbols in Suzanne Collins' The Hunger Games
# 3.125792 The Hunger Games Tribute Guide
#
# Item title: The Book Thief
# Similar items are:
# 5.1500897 The Book Thief
# 3.9669297 I Am the Messenger
# 3.418836 Twelve Years a Slave
# 3.3060427 And the Mountains Echoed (Thorndike Press Large Print Basic Series)
# 3.166543 Orphan Train
# 3.0499651 Twice Born: A Novel
# 3.035609 The Storyteller
# 3.025488 Orphan Train: A Novel
# 2.993997 The Invention of Wings: A Novel
# 2.9755332 The Madonnas of Leningrad: A Novel
#
# Item title: Sycamore Row
# Similar items are:
# 4.605032 Sycamore Row
# 3.996304 The Racketeer
# 3.661461 N/A
# 3.608979 Be Careful What You Wish For (The Clifton Chronicles)
# 3.49021 Theodore Boone: The Accused
# 3.451087 King and Maxwell (King &amp; Maxwell Series)
# 3.419634 The Target
# 3.4066954 Best Kept Secret (The Clifton Chronicles)
# 3.3976998 Theodore Boone: The Activist (Theodore Boone: Kid Lawyer)
# 3.3882475 The Litigators
#
# Item title: Mockingjay (The Final Book of The Hunger Games)
# Similar items are:
# 5.4142942 Mockingjay (The Final Book of The Hunger Games)
# 5.338859 The Hunger Games (The Hunger Games, Book 1)
# 5.198169 Catching Fire (The Hunger Games, Book 2)
# 4.8639827 Catching Fire (The Hunger Games, Book 2)
# 3.6712294 Dream Cat
# 3.4309156 Catching Fire
# 3.142386 Katniss the Cattail: An Unauthorized Guide to Names and Symbols in Suzanne Collins' The Hunger Games
# 3.1423712 Class A (CHERUB #2) (Bk. 2)
# 3.1146958 The Hunger Games: Official Illustrated Movie Companion
# 3.0353856 The Hunger Games Tribute Guide
#
# Item title: The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# Similar items are:
# 4.259714 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 3.8217447 All the Light We Cannot See: A Novel
# 3.6796737 Life After Life: A Novel
# 3.6717865 Flight Behavior: A Novel
# 3.6257443 The Signature of All Things: A Novel
# 3.5828319 And the Mountains Echoed (Thorndike Press Large Print Basic Series)
# 3.56564 Someone: A Novel
# 3.5585895 The Luminaries: A Novel (Man Booker Prize)
# 3.550615 The Burgess Boys: A Novel
# 3.5400121 The Lowland
#
# Item title: Inferno
# Similar items are:
# 5.0684385 Inferno
# 4.0383644 N/A
# 3.4347856 N/A
# 3.3560042 N/A
# 3.335934 The King's Deception: A Novel (Cotton Malone)
# 3.3208356 The Mayan Secrets (A Fargo Adventure)
# 3.2915893 The Lost Symbol
# 3.2885509 The Tournament
# 3.286287 The English Girl: A Novel (Gabriel Allon)
# 3.2674694 N/A
#
# Item title: Allegiant (Divergent, #3)
# Similar items are:
# 4.8301873 Allegiant (Divergent, #3)
# 4.7004576 Insurgent (Divergent)
# 4.578815 Divergent (Turtleback School &amp; Library Binding Edition) (Divergent Trilogy)
# 4.3942127 N/A
# 4.3792133 Divergent
# 4.175354 N/A
# 4.01411 Champion (Legend, #3)
# 3.9700797 N/A
# 3.880477 N/A
# 3.8214335 The Kill Order (Maze Runner, Prequel) (The Maze Runner Series)
#
# Item title: Hopeless
# Similar items are:
# 4.408144 Hopeless
# 3.9678433 The Edge of Never
# 3.8897114 The Coincidence of Callie &amp; Kayden
# 3.8746533 The Secret of Ella and Micha
# 3.8354926 Barely Breathing: The Breathing Series (Volume 2)
# 3.8265567 Slammed
# 3.8122435 The Perfect Game: A Novel (The Game Series, Book One)
# 3.7900887 Point of Retreat
# 3.7730758 Left Drowning
# 3.752964 Lost To You (The Regret Series)

# %%
eval_user_recommendations(bpr_item_embs_fn, bpr_user_embs_fn)
# Out:
# For the user with history:
# Gone Girl
# The Dog Stars (Vintage Contemporaries)
# Fahrenheit 451 Low Price CD
# Ready Player One
# Recommendations are are:
# 2.737611 The Dog Stars (Vintage Contemporaries)
# 2.5838308 Ready Player One
# 2.4328501 Age of Miracles, the (Lib)(CD)
# 2.4078915 The Fifty Year Sword
# 2.3656206 Robopocalypse: A Novel (Vintage Contemporaries)
# 2.2266612 Invisible Monsters Remix
# 2.2078996 The Mirage: A Novel
# 2.1832147 The Year of the Flood
# 2.167082 The Collective: A Novel
# 2.156073 The Last Policeman
#
# For the user with history:
# One Last Thing Before I Go: A Novel
# Sacre Bleu: A Comedy d'Art
# Fahrenheit 451 Low Price CD
# The Time Keeper
# How to Talk to a Widower
# The Adventures of Sherlock Holmes (Dover Thrift Editions)
# The Casual Vacancy
# Brain on Fire: My Month of Madness
# Unbroken
# The Martian Chronicles (Harper Perennial Modern Classics)
# The Twelve Tribes of Hattie (Vintage)
# The Round House
# When She Woke
# Mr. Penumbra's 24-Hour Bookstore: A Novel
# The Elegance of the Hedgehog
# The Bungalow: A Novel
# The Language of Flowers
# Juliet, Naked
# Sharp Objects: A Novel
# Tell the Wolves I'm Home: A Novel
# Recommendations are are:
# 2.1257439 Tell the Wolves I'm Home: A Novel
# 2.1197135 The Dinner
# 2.078585 Life After Life: A Novel
# 2.0594978 Gone Girl
# 2.0546293 Where'd You Go, Bernadette: A Novel
# 2.052473 This Is Where I Leave You: A Novel
# 2.0202413 The Unlikely Pilgrimage of Harold Fry: A Novel
# 2.0168097 One Last Thing Before I Go: A Novel
# 2.0101557 The Marriage Plot
# 2.0047219 State of Wonder
#
# For the user with history:
# Dr. Atkins' New Diet Revolution
# N/A
# Eifelheim
# Charlotte Collins: A Continuation of Jane Austen's Pride and Prejudice
# Recommendations are are:
# 1.6319153 N/A
# 1.6036481 The Kingdom by the Sea: A Journey Around the Coast of Great Britain
# 1.5928662 Pemberley to Waterloo: Georgiana Darcy's Diary, Volume 2
# 1.5396987 Kitty Bennet's Diary (Pride and Prejudice Chronicles) (Volume 3)
# 1.5377071 The Darcys of Pemberley: The Continuing Story of Jane Austen's Pride and Prejudice
# 1.5054678 Return To Longbourn: The Next Chapter in the Continuing Story of Jane Austen's Pride and Prejudice
# 1.4723877 N/A
# 1.4521912 The Highbury Murders: A Mystery Set in the Village of Jane Austen's Emma
# 1.4506999 Lady Fortescue Steps Out (The Poor Relation)
# 1.4491317 N/A
#
# For the user with history:
# N/A
# Deeper
# Beyond Me: Sex on the Beach
# Deadland's Harvest (Deadland Saga) (Volume 2)
# Against All Odds
# N/A
# Frenched (Volume 1)
# Falling Into You
# Bend: The Complete Banned Anthology
# Beg Tease Submit - Sequence One (Songs of Submission)
# N/A
# Sing (Songs of Submission) (Volume 7)
# N/A
# Taking Chances
# N/A
# Spin (Songs of Corruption) (Volume 1)
# Chasing Beautiful (Chasing Series Book)
# Good (Too Good)
# Better (Too Good)
# Beautiful Broken Rules
# Recommendations are are:
# 3.002103 N/A
# 3.00172 Sex Love Repeat
# 2.930127 Raw
# 2.9254434 Sing (Songs of Submission) (Volume 7)
# 2.924678 Frenched (Volume 1)
# 2.90997 Fixed on You (Volume 1)
# 2.907713 Behind His Eyes - Consequences: Reading Companion to the Bestselling Consequences Series
# 2.9051604 Bend: The Complete Banned Anthology
# 2.9044437 N/A
# 2.8994977 Behind His Eyes - Truth (Reading Companion to the bestselling Consequences Series) (Volume 5)
#
# For the user with history:
# Pickle-Chiffon Pie
# Insane City
# The Brilliant Disaster: JFK, Castro, and America's Doomed Invasion of Cuba's Bay of Pigs
# Forrest Gump (Movie Tie in)
# Younger Next Year: A Guide to Living Like 50 Until You're 80 and Beyond
# Recommendations are are:
# 1.7892967 The Catcher Was a Spy: The Mysterious Life of Moe Berg
# 1.7186712 Hollowing Out the Middle: The Rural Brain Drain and What It Means for America
# 1.6929395 Tammy Wynette: Tragic Country Queen
# 1.6766127 Crazy U: One Dad's Crash Course in Getting His Kid Into College
# 1.6531776 Americana: Dispatches from the New Frontier
# 1.638341 Chasing Moonlight: The True Story of Field of Dreams' Doc Graham
# 1.6369145 The Big Rich: The Rise and Fall of the Greatest Texas Oil Fortunes
# 1.6338682 The Beckham Experiment: How the World's Most Famous Athlete Tried to Conquer America
# 1.6261158 The Billionaire Who Wasn't: How Chuck Feeney Made and Gave Away a Fortune Without Anyone Knowing
# 1.6259853 The Fifth Season: Tales of My Life in Baseball
#
# For the user with history:
# N/A
# N/A
# N/A
# N/A
# Recommendations are are:
# 3.207055 N/A
# 3.1969442 N/A
# 3.1935778 N/A
# 3.1808033 N/A
# 3.179749 Red's Bear (Erotic Shifter Fairy Tales)
# 3.1506827 Love Intertwined Vol. 1: Three Tales of Interracial Romance and Eroticism (Volume 1)
# 3.1383278 N/A
# 3.1269493 N/A
# 3.1167707 The Admission
# 3.1155653 N/A
#
# For the user with history:
# Baby Catcher: Chronicles of a Modern Midwife
# Witches, Midwives, and Nurses: A History of Women Healers (Contemporary Classics)
# The Belly Book: A Nine-Month Journal for You and Your Growing Belly (Potter Style)
# Spoon
# Chopsticks
# Recommendations are are:
# 2.8549094 Amazing You!: Getting Smart About Your Private Parts
# 2.8128657 Q&amp;A a Day for Kids: A Three-Year Journal
# 2.8102665 The Mommy Journal: Letters To Your Child
# 2.7674193 Look, Look!
# 2.7634563 Teeth Are Not for Biting (Board Book) (Best Behavior Series)
# 2.7514732 Playful Parenting
# 2.7449198 Where Is Baby's Birthday Cake?: A Lift-the-Flap Book (Karen Katz Lift-the-Flap Books)
# 2.7403295 Spoon
# 2.7363126 Momma Zen: Walking the Crooked Path of Motherhood
# 2.7347522 The Baby Book: Everything You Need to Know About Your Baby from Birth to Age Two (Revised and Updated Edition)
#
# For the user with history:
# A Sea of Troubles (John Pearce 9)
# Little Dorrit (Penguin Classics)
# The Cloud Collector's Handbook
# Buddhism for Beginners
# The Shadow of the Eagle: #13 A Nathaniel Drinkwater Novel (Mariners Library Fiction Classic)
# Overnight Colon and Liver Cleanse &amp; Detox: Get Your Energy, Stamina and Mental Clarity Back in 11 days and Lose Weight Fast in the Process!
# Ben-Hur (Oxford World's Classics)
# Recommendations are are:
# 1.5068566 Vagabonding in Europe and North Africa
# 1.4959066 The Secret of the Great Pyramid: How One Man's Obsession Led to the Solution of Ancient Egypt's Greatest Mystery
# 1.4871435 Augustine and the Jews: A Christian Defense of Jews and Judaism
# 1.4850472 Little Dorrit (Penguin Classics)
# 1.474256 Sir Nigel
# 1.4673682 Three Men on the Bummel
# 1.4570401 The City Tavern Cookbook: Recipes from the Birthplace of American Cuisine
# 1.4545381 The Black Camel
# 1.4500709 Under Kilimanjaro
# 1.4493444 The Vinland Sagas: The Norse Discovery of America (Penguin Classics)
#
# For the user with history:
# A Singular Woman: The Untold Story of Barack Obama's Mother
# N/A
# Agatha Raisin and the Fairies of Fryfam (Agatha Raisin Mysteries, No. 10)
# The Walkers of Dembley (Agatha Raisin Mysteries)
# Recommendations are are:
# 2.1279395 The Ghost and Mrs. Jeffries (Victorian Mystery)
# 2.100981 Agatha Raisin and the Fairies of Fryfam (Agatha Raisin Mysteries, No. 10)
# 2.0658832 Death of a Gossip (Hamish Macbeth Mysteries, No. 1)
# 2.0650644 Snowballs and Scotch Mist: The Belchester Chronicles - 3
# 2.0634477 N/A
# 2.0585048 The Marriage Certificate
# 2.042174 Mrs. Jeffries Questions the Answer (Victorian Mystery)
# 2.041934 Grounds for Murder (Pennyfoot Hotel Mysteries)
# 2.012199 Agatha Raisin and the Haunted House (Agatha Raisin Mysteries, No. 14)
# 2.0114067 N/A
#
# For the user with history:
# N/A
# N/A
# Amish Faith: An Amish Christian Romance
# Fields of Corn: The Amish of Lancaster
# Hills of Wheat: The Amish of Lancaster Series
# Ozark Sweetheart (Heartsong Presents)
# N/A
# Recommendations are are:
# 3.353175 Amish Faith: An Amish Christian Romance
# 3.3317802 Hills of Wheat: The Amish of Lancaster Series
# 3.3226507 Wild Horses: Another spirited novel by the bestselling Amish author! (Sadie's Montana)
# 3.2978554 THE KENTUCKY BROTHERS TRILOGY
# 3.2899938 Fields of Corn: The Amish of Lancaster
# 3.2882802 The Quilter's Son: Book Four: Maddie's Quilt
# 3.2827284 Amish by Accident
# 3.2656264 Plain Change: The Plain Fame Trilogy
# 3.2599506 Plain Fame: The Plain Fame Trilogy
# 3.256323 A Home for Hannah (Love Inspired)

# %% [markdown]
# # 3. Neural Collaborative Filtering

# %% [markdown]
# For the Neural Collaborative Filtering model, I use the model where the user embedding is not just an average of the items from the recent history, but it is also mapped through the trainable dense layer to the hidden layer (the size of which is equal to the embedding size).
#
# The user embedding is then used to optimize the inner product with the item following in history. The optimization is done through sampled (since there are 367964 items) softmax loss for the correct item along with negative samples.

# %%
embedding_dim = 64
hidden_size = 64
lr = 0.005

gpu_options = tf.GPUOptions(allow_growth=True)

sess_dnn = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
model_dnn = modeling.Model_DNN(item_count, embedding_dim, hidden_size, batch_size, maxlen)

sess_dnn.run(tf.global_variables_initializer())
sess_dnn.run(tf.local_variables_initializer())
# Out:
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:24: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:35: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/zerogerc/anaconda3/envs/books/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:98: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1364d84198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1364d84198>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1364d84198>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f1364d84198>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:55: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %%
def dnn_item_embs_fn():
  return model_dnn.output_item(sess_dnn)

# %%
def dnn_user_embs_fn(hist_item_list, hist_mask_list):
  user_embs = model_dnn.output_user(sess_dnn, [hist_item_list, hist_mask_list])
  return user_embs

# %%
start_time = time.time()

max_iters = 20000
test_iter = 1000
valid_best_recall = 0.0
valid_best_iter = 0
train_data_iter = iter(train_data)

loss_sum = 0.0
for iters in range(1, max_iters + 1):
  src, tgt = next(train_data_iter)
  (user_id_list, item_id_list), (hist_item_list, hist_mask_list) = src, tgt
  loss = model_dnn.train(sess_dnn, [user_id_list, item_id_list, hist_item_list, hist_mask_list, lr])
  loss_sum += loss

  if iters % test_iter == 0:
    test_time = time.time()
    valid_metrics = eval_model_on(
        data_iter=valid_data,
        item_embs_fn=dnn_item_embs_fn,
        user_embs_fn=dnn_user_embs_fn)
    print(f"iters: {iters}")
    print(f"train loss: {loss_sum / test_iter}")
    print(f"valid metrics: {valid_metrics}")
    print(f"time spent so far: {((time.time() - start_time) / 60.0):.3f}m")
    loss_sum = 0.0
    
    valid_recall = valid_metrics["recall"]
    if valid_recall > valid_best_recall:
      valid_best_recall = valid_recall
      valid_best_iter = iters
    
    if iters - valid_best_iter >= 5 * test_iter:
      print('early stopping criterion is met')
      break
# Out:
# iters: 1000
# train loss: 7.588786633968353
# valid metrics: {'users': 60367, 'recall': 0.03216566536780674, 'ndcg': 0.013776011606282003, 'hitrate': 0.07330163831232296}
# time spent so far: 1.522m
# iters: 2000
# train loss: 6.906737147331238
# valid metrics: {'users': 60367, 'recall': 0.04243955138380641, 'ndcg': 0.018304352188938375, 'hitrate': 0.09390892374973081}
# time spent so far: 3.045m
# iters: 3000
# train loss: 6.39157055568695
# valid metrics: {'users': 60367, 'recall': 0.05105718947374024, 'ndcg': 0.02220283882575626, 'hitrate': 0.11330693922176023}
# time spent so far: 4.569m
# iters: 4000
# train loss: 5.953585556507111
# valid metrics: {'users': 60367, 'recall': 0.05474238606220706, 'ndcg': 0.024337278849042195, 'hitrate': 0.12115891132572432}
# time spent so far: 6.093m
# iters: 5000
# train loss: 5.605281569004059
# valid metrics: {'users': 60367, 'recall': 0.05916667184388413, 'ndcg': 0.026564492986180445, 'hitrate': 0.1285636191959183}
# time spent so far: 7.618m
# iters: 6000
# train loss: 5.3066994976997375
# valid metrics: {'users': 60367, 'recall': 0.06143813019320296, 'ndcg': 0.02748464548231508, 'hitrate': 0.13351665645137245}
# time spent so far: 9.141m
# iters: 7000
# train loss: 5.048690008163452
# valid metrics: {'users': 60367, 'recall': 0.06513358298932506, 'ndcg': 0.02903993879510313, 'hitrate': 0.14057349213974524}
# time spent so far: 10.666m
# iters: 8000
# train loss: 4.833466978549957
# valid metrics: {'users': 60367, 'recall': 0.0656045509661827, 'ndcg': 0.029911431006406017, 'hitrate': 0.14191528484105553}
# time spent so far: 12.191m
# iters: 9000
# train loss: 4.668540984153748
# valid metrics: {'users': 60367, 'recall': 0.06709377081740697, 'ndcg': 0.03051681934962116, 'hitrate': 0.1449136117415144}
# time spent so far: 13.715m
# iters: 10000
# train loss: 4.496770542860031
# valid metrics: {'users': 60367, 'recall': 0.06737412069573084, 'ndcg': 0.030750891357758152, 'hitrate': 0.1458081402090546}
# time spent so far: 15.240m
# iters: 11000
# train loss: 4.362134969234466
# valid metrics: {'users': 60367, 'recall': 0.06944769707534974, 'ndcg': 0.03177108923908221, 'hitrate': 0.14963473420908774}
# time spent so far: 16.765m
# iters: 12000
# train loss: 4.256209474563598
# valid metrics: {'users': 60367, 'recall': 0.06922429074433857, 'ndcg': 0.031540576729403226, 'hitrate': 0.1489224245034539}
# time spent so far: 18.291m
# iters: 13000
# train loss: 4.157718918085099
# valid metrics: {'users': 60367, 'recall': 0.06846145048487143, 'ndcg': 0.031667280423079064, 'hitrate': 0.14850829095366674}
# time spent so far: 19.816m
# iters: 14000
# train loss: 4.076381288051605
# valid metrics: {'users': 60367, 'recall': 0.06905775458429271, 'ndcg': 0.03172567143219509, 'hitrate': 0.14903838189739427}
# time spent so far: 21.341m
# iters: 15000
# train loss: 3.972921020746231
# valid metrics: {'users': 60367, 'recall': 0.07000588827218925, 'ndcg': 0.031997204597332636, 'hitrate': 0.1520698394818361}
# time spent so far: 22.867m
# iters: 16000
# train loss: 3.9071859686374664
# valid metrics: {'users': 60367, 'recall': 0.07080678419512376, 'ndcg': 0.0324351354807916, 'hitrate': 0.1528649758974274}
# time spent so far: 24.392m
# iters: 17000
# train loss: 3.847059267282486
# valid metrics: {'users': 60367, 'recall': 0.07177000504839866, 'ndcg': 0.032992252368459006, 'hitrate': 0.1553497771961502}
# time spent so far: 25.918m
# iters: 18000
# train loss: 3.789541753768921
# valid metrics: {'users': 60367, 'recall': 0.0711785480382942, 'ndcg': 0.03307471635001309, 'hitrate': 0.1532128480792486}
# time spent so far: 27.442m
# iters: 19000
# train loss: 3.721624332666397
# valid metrics: {'users': 60367, 'recall': 0.07047896716502909, 'ndcg': 0.03238938187949748, 'hitrate': 0.1521857968757765}
# time spent so far: 28.968m
# iters: 20000
# train loss: 3.663212366104126
# valid metrics: {'users': 60367, 'recall': 0.07232827204716764, 'ndcg': 0.032946639639377724, 'hitrate': 0.15551543061606507}
# time spent so far: 30.493m

# %% [markdown]
# ## NCF Quantitative evaluation

# %%
test_metrics = eval_model_on(
    data_iter=test_data,
    item_embs_fn=dnn_item_embs_fn,
    user_embs_fn=dnn_user_embs_fn)
print(f"test metrics: {test_metrics}")
# Out:
# test metrics: {'users': 60367, 'recall': 0.06991044218893151, 'ndcg': 0.03219544022900266, 'hitrate': 0.15322941342124008}

# %%
model_metrics['DNN'] = test_metrics

# %% [markdown]
# ## NCF Qualitative evaluation

# %%
eval_similar_items(dnn_item_embs_fn)
# Out:
# Item title: Gone Girl
# Similar items are:
# 33.14178 Gone Girl
# 28.836876 Inferno
# 27.388721 The Hunger Games (The Hunger Games, Book 1)
# 27.272175 Sycamore Row
# 27.162636 The Book Thief
# 27.100647 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 25.947153 Doctor Sleep: A Novel
# 25.860832 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 25.31991 Allegiant (Divergent, #3)
# 24.784689 Fifty Shades of Grey: Book One of the Fifty Shades Trilogy
#
# Item title: The Hunger Games (The Hunger Games, Book 1)
# Similar items are:
# 37.68365 The Hunger Games (The Hunger Games, Book 1)
# 29.933704 Inferno
# 27.731993 The Book Thief
# 27.72144 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 27.388721 Gone Girl
# 26.577408 Fifty Shades of Grey: Book One of the Fifty Shades Trilogy
# 26.396591 Allegiant (Divergent, #3)
# 25.734365 Under The Dome: A Novel
# 25.57756 Insurgent (Divergent)
# 25.371483 Unbroken
#
# Item title: The Book Thief
# Similar items are:
# 32.354 The Book Thief
# 28.441608 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 27.731993 The Hunger Games (The Hunger Games, Book 1)
# 27.335516 Inferno
# 27.162636 Gone Girl
# 26.1039 Sycamore Row
# 24.949177 Doctor Sleep: A Novel
# 24.645767 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 24.409782 Unbroken
# 23.946953 Allegiant (Divergent, #3)
#
# Item title: Sycamore Row
# Similar items are:
# 33.57597 Sycamore Row
# 29.291965 Inferno
# 27.789059 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 27.272175 Gone Girl
# 26.33249 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 26.1039 The Book Thief
# 25.85783 The Cuckoo's Calling
# 25.516455 The Atlantis Gene: A Thriller (The Origin Mystery, Book 1)
# 25.276169 Proof of Heaven: A Neurosurgeon's Near-Death Experience and Journey into the Afterlife
# 25.11609 The Hunger Games (The Hunger Games, Book 1)
#
# Item title: Mockingjay (The Final Book of The Hunger Games)
# Similar items are:
# 27.518097 Mockingjay (The Final Book of The Hunger Games)
# 24.434448 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 23.409517 Gone Girl
# 22.471895 The Hunger Games Trilogy Boxed Set
# 21.978445 The Hunger Games (The Hunger Games, Book 1)
# 21.938616 Sycamore Row
# 21.104021 Allegiant (Divergent, #3)
# 20.53987 Fifty Shades of Grey: Book One of the Fifty Shades Trilogy
# 20.220274 The Book Thief
# 20.202066 Ender's Game (The Ender Quintet)
#
# Item title: The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# Similar items are:
# 31.388203 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 28.370697 Inferno
# 27.789059 Sycamore Row
# 25.860832 Gone Girl
# 25.652653 The Cuckoo's Calling
# 24.645767 The Book Thief
# 24.478691 The Hunger Games (The Hunger Games, Book 1)
# 23.995459 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 23.785568 Proof of Heaven: A Neurosurgeon's Near-Death Experience and Journey into the Afterlife
# 22.671541 Doctor Sleep: A Novel
#
# Item title: Inferno
# Similar items are:
# 35.0277 Inferno
# 29.933704 The Hunger Games (The Hunger Games, Book 1)
# 29.291965 Sycamore Row
# 28.836876 Gone Girl
# 28.370697 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 28.13324 The Cuckoo's Calling
# 27.335516 The Book Thief
# 26.59552 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 26.384846 Doctor Sleep: A Novel
# 25.752947 Under The Dome: A Novel
#
# Item title: Allegiant (Divergent, #3)
# Similar items are:
# 34.192112 Allegiant (Divergent, #3)
# 26.93953 Heaven is for Real Movie Edition: A Little Boy's Astounding Story of His Trip to Heaven and Back
# 26.396591 The Hunger Games (The Hunger Games, Book 1)
# 25.31991 Gone Girl
# 24.32797 Inferno
# 23.946953 The Book Thief
# 23.393631 Sycamore Row
# 22.978273 A Game of Thrones: A Song of Ice and Fire: Book One
# 22.898172 The Cuckoo's Calling
# 22.499834 Insurgent (Divergent)
#
# Item title: Hopeless
# Similar items are:
# 17.517336 Hopeless
# 14.843264 Allegiant (Divergent, #3)
# 14.6962185 The Hunger Games (The Hunger Games, Book 1)
# 14.543436 Fifty Shades Darker
# 14.510278 The Husband's Secret
# 14.450431 Gone Girl
# 13.81572 Safe Haven
# 13.734225 Inferno
# 13.339431 Six Years
# 13.270416 Insurgent (Divergent)

# %%
eval_user_recommendations(dnn_item_embs_fn, dnn_user_embs_fn)
# Out:
# For the user with history:
# Gone Girl
# The Dog Stars (Vintage Contemporaries)
# Fahrenheit 451 Low Price CD
# Ready Player One
# Recommendations are are:
# 12.158984 The Book Thief
# 11.356752 Ready Player One
# 11.200513 The Casual Vacancy
# 11.031932 Fahrenheit 451 Low Price CD
# 11.010069 Life After Life: A Novel
# 10.998772 2Br02B
# 10.634503 Where'd You Go, Bernadette: A Novel
# 10.631555 Zealot: The Life and Times of Jesus of Nazareth
# 10.593879 Red Rising
# 10.488182 Bad Monkey
#
# For the user with history:
# One Last Thing Before I Go: A Novel
# Sacre Bleu: A Comedy d'Art
# Fahrenheit 451 Low Price CD
# The Time Keeper
# How to Talk to a Widower
# The Adventures of Sherlock Holmes (Dover Thrift Editions)
# The Casual Vacancy
# Brain on Fire: My Month of Madness
# Unbroken
# The Martian Chronicles (Harper Perennial Modern Classics)
# The Twelve Tribes of Hattie (Vintage)
# The Round House
# When She Woke
# Mr. Penumbra's 24-Hour Bookstore: A Novel
# The Elegance of the Hedgehog
# The Bungalow: A Novel
# The Language of Flowers
# Juliet, Naked
# Sharp Objects: A Novel
# Tell the Wolves I'm Home: A Novel
# Recommendations are are:
# 10.391171 Life After Life: A Novel
# 9.709864 Defending Jacob: A Novel
# 9.6214285 The Unlikely Pilgrimage of Harold Fry: A Novel
# 9.619929 The Light Between Oceans
# 9.470739 Gone Girl
# 9.295906 The Invention of Wings: A Novel
# 9.139814 Where'd You Go, Bernadette: A Novel
# 9.098433 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 8.992043 The Dinner
# 8.945903 A Tale for the Time Being: A Novel
#
# For the user with history:
# Dr. Atkins' New Diet Revolution
# N/A
# Eifelheim
# Charlotte Collins: A Continuation of Jane Austen's Pride and Prejudice
# Recommendations are are:
# 9.118501 I Know Why the Caged Bird Sings
# 8.607641 Slow Getting Up: A Story of NFL Survival from the Bottom of the Pile
# 8.087924 Loving Our Kids On Purpose: Making A Heart-To-Heart Connection
# 8.038015 The Minor Adjustment Beauty Salon (No. 1 Ladies' Detective Agency)
# 7.838038 Pain Free: A Revolutionary Method for Stopping Chronic Pain
# 7.6919866 The Healing Code: 6 Minutes to Heal the Source of Your Health, Sucess or Relationship Issue
# 7.6893992 A Year of Biblical Womanhood: How a Liberated Woman Found Herself Sitting on Her Roof, Covering Her Head, and Calling Her Husband &quot;Master&quot;
# 7.5638027 Shanghai Girls: A Novel
# 7.5061684 The Case for Christ:  A Journalist's Personal Investigation of the Evidence for Jesus
# 7.4477453 Physician
#
# For the user with history:
# N/A
# Deeper
# Beyond Me: Sex on the Beach
# Deadland's Harvest (Deadland Saga) (Volume 2)
# Against All Odds
# N/A
# Frenched (Volume 1)
# Falling Into You
# Bend: The Complete Banned Anthology
# Beg Tease Submit - Sequence One (Songs of Submission)
# N/A
# Sing (Songs of Submission) (Volume 7)
# N/A
# Taking Chances
# N/A
# Spin (Songs of Corruption) (Volume 1)
# Chasing Beautiful (Chasing Series Book)
# Good (Too Good)
# Better (Too Good)
# Beautiful Broken Rules
# Recommendations are are:
# 11.550048 N/A
# 10.665624 N/A
# 10.662426 Tethered
# 10.434694 N/A
# 10.401618 N/A
# 10.383354 N/A
# 10.322725 N/A
# 10.288764 Sex Love Repeat
# 10.078986 N/A
# 10.033688 Broken Wings
#
# For the user with history:
# Pickle-Chiffon Pie
# Insane City
# The Brilliant Disaster: JFK, Castro, and America's Doomed Invasion of Cuba's Bay of Pigs
# Forrest Gump (Movie Tie in)
# Younger Next Year: A Guide to Living Like 50 Until You're 80 and Beyond
# Recommendations are are:
# 8.362419 No Easy Day: The Autobiography of a Navy Seal: The Firsthand Account of the Mission That Killed Osama Bin Laden
# 8.079276 Under The Dome: A Novel
# 7.7584066 The Ultimate Man's Survival Guide: Rediscovering the Lost Art of Manhood
# 7.3675604 Killing Jesus
# 7.21912 Duty: Memoirs of a Secretary at War
# 7.2021766 A Most Wanted Man
# 7.0746107 Divergent (Book 1) (Divergent Series)
# 6.9733634 Sycamore Row
# 6.925682 Inferno
# 6.87236 Kill Anything That Moves: The Real American War in Vietnam
#
# For the user with history:
# N/A
# N/A
# N/A
# N/A
# Recommendations are are:
# 12.459475 N/A
# 11.882804 N/A
# 11.03047 Forgive Me Father For I Have Loved
# 10.820449 His One and Only (50 Loving States) (Volume 6)
# 10.784357 N/A
# 10.729829 N/A
# 10.428543 N/A
# 10.383666 N/A
# 10.205673 N/A
# 10.097421 N/A
#
# For the user with history:
# Baby Catcher: Chronicles of a Modern Midwife
# Witches, Midwives, and Nurses: A History of Women Healers (Contemporary Classics)
# The Belly Book: A Nine-Month Journal for You and Your Growing Belly (Potter Style)
# Spoon
# Chopsticks
# Recommendations are are:
# 12.299681 My First Touch &amp; Feel Picture Cards: First Words (MY 1ST T&amp;F PICTURE CARDS)
# 10.393381 The Day the Crayons Quit
# 10.022804 The Belly Book: A Nine-Month Journal for You and Your Growing Belly (Potter Style)
# 9.354477 Panda Bear, Panda Bear, What Do You See?
# 9.2907295 The Glass Castle
# 9.208631 The Happiness Project: Or, Why I Spent a Year Trying to Sing in the Morning, Clean My Closets, Fight Right, Read Aristotle, and Generally Have More Fun
# 9.198847 The Nursing Mother's Companion: Revised Edition
# 9.119366 The Happiest Baby on the Block
# 9.068168 On the Island (Plume Book)
# 9.036309 Love You Forever
#
# For the user with history:
# A Sea of Troubles (John Pearce 9)
# Little Dorrit (Penguin Classics)
# The Cloud Collector's Handbook
# Buddhism for Beginners
# The Shadow of the Eagle: #13 A Nathaniel Drinkwater Novel (Mariners Library Fiction Classic)
# Overnight Colon and Liver Cleanse &amp; Detox: Get Your Energy, Stamina and Mental Clarity Back in 11 days and Lose Weight Fast in the Process!
# Ben-Hur (Oxford World's Classics)
# Recommendations are are:
# 5.5690346 Sycamore Row
# 5.3529334 Nourishing Meals: Healthy Gluten-Free Recipes for the Whole Family
# 5.35187 Life Itself: A Memoir
# 5.314478 Good Tidings and Great Joy: Protecting the Heart of Christmas
# 5.214203 America the Beautiful: Rediscovering What Made This Nation Great
# 5.209767 Those Angry Days: Roosevelt, Lindbergh, and America's Fight Over World War II, 1939-1941
# 5.1765175 How to Make a Towel Monkey and other Cruise Ship Favorites
# 5.0679812 Moonwalking with Einstein: The Art and Science of Remembering Everything
# 5.0539794 The Pagan Lord: A Novel (Saxon Tales)
# 5.010067 The House of Silk: A Sherlock Holmes Novel
#
# For the user with history:
# A Singular Woman: The Untold Story of Barack Obama's Mother
# N/A
# Agatha Raisin and the Fairies of Fryfam (Agatha Raisin Mysteries, No. 10)
# The Walkers of Dembley (Agatha Raisin Mysteries)
# Recommendations are are:
# 11.557898 Conundrums for the Long Week-End : England, Dorothy L. Sayers, and Lord Peter Wimsey
# 10.999459 The Walkers of Dembley (Agatha Raisin Mysteries)
# 10.676313 Hiss and Hers: An Agatha Raisin Mystery (Agatha Raisin Mysteries)
# 10.633117 A Future Arrived: A Novel (Greville Family Saga)
# 10.44174 India Black and the Shadows of Anarchy (A Madam of Espionage Mystery)
# 10.267748 Nancy Drew Starter Set
# 10.167355 N/A
# 10.126523 City of Darkness and Light (Molly Murphy Mysteries)
# 10.059596 Tips From The Cruise Addict's Wife: Tips and Tricks to Plan the Best Cruise Vacation Ever!
# 9.983828 The Golden Egg (Commissario Guido Brunetti)
#
# For the user with history:
# N/A
# N/A
# Amish Faith: An Amish Christian Romance
# Fields of Corn: The Amish of Lancaster
# Hills of Wheat: The Amish of Lancaster Series
# Ozark Sweetheart (Heartsong Presents)
# N/A
# Recommendations are are:
# 11.369288 Fields of Corn: The Amish of Lancaster
# 11.052688 Valley of Hope: The Amish of Lancaster
# 10.923383 Amish Circle Letters - The Complete Series
# 10.615107 Holding a Tender Heart (The Beiler Sisters)
# 10.6058855 Plain Fame: The Plain Fame Trilogy
# 10.366662 Chasing Sunsets: A Cedar Key Novel
# 10.232617 N/A
# 10.093881 Amish Faith: An Amish Christian Romance
# 10.055019 Goodbye to Yesterday: Part 1 (The Discovery - A Lancaster County Saga)
# 10.007501 Amish by Accident

# %% [markdown]
# # 4. Self-Attention model

# %% [markdown]
# As for the last model, I use the self-attention block to compute the user embedding from the items in the history. The attention logits are computed from item embeddings + positional encoding. The logits are then normalized using softmax.
#
# The final user vector is computed as the weighted sum of the attention weights and item embeddings. In contrast, the previous model just takes the average of the item embeddings.
#
# I leave the optimization procedure from the previous model unchanged.

# %%
embedding_dim = 64
hidden_size = 64
num_heads = 1
lr = 0.005

gpu_options = tf.GPUOptions(allow_growth=True)

sess_sa = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
model_sa = modeling.Model_SA(item_count, embedding_dim, hidden_size, batch_size, num_heads, maxlen)

sess_sa.run(tf.global_variables_initializer())
sess_sa.run(tf.local_variables_initializer())
# Out:
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:119: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:119: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7f136480dc50>>: AttributeError: module 'gast' has no attribute 'Index'
# WARNING:tensorflow:From /data/msazanovich/recommender-systems/modeling.py:127: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
def sa_item_embs_fn():
  return model_sa.output_item(sess_sa)

# %%
def sa_user_embs_fn(hist_item_list, hist_mask_list):
  user_embs = model_sa.output_user(sess_sa, [hist_item_list, hist_mask_list])
  user_embs = np.squeeze(user_embs, axis=1)
  return user_embs

# %%
start_time = time.time()

max_iters = 20000
test_iter = 1000
valid_best_recall = 0.0
valid_best_iter = 0
train_data_iter = iter(train_data)

loss_sum = 0.0
for iters in range(1, max_iters + 1):
  src, tgt = next(train_data_iter)
  (user_id_list, item_id_list), (hist_item_list, hist_mask_list) = src, tgt
  loss = model_sa.train(sess_sa, [user_id_list, item_id_list, hist_item_list, hist_mask_list, lr])
  loss_sum += loss

  if iters % test_iter == 0:
    test_time = time.time()
    valid_metrics = eval_model_on(
        data_iter=valid_data,
        item_embs_fn=sa_item_embs_fn,
        user_embs_fn=sa_user_embs_fn)
    print(f"iters: {iters}")
    print(f"train loss: {loss_sum / test_iter}")
    print(f"valid metrics: {valid_metrics}")
    print(f"time spent so far: {((time.time() - start_time) / 60.0):.3f}m")
    loss_sum = 0.0
    
    valid_recall = valid_metrics["recall"]
    if valid_recall > valid_best_recall:
      valid_best_recall = valid_recall
      valid_best_iter = iters

    if iters - valid_best_iter >= 5 * test_iter:
      print('early stopping criterion is met')
      break
# Out:
# iters: 1000
# train loss: 7.84919075345993
# valid metrics: {'users': 60367, 'recall': 0.0309384783144264, 'ndcg': 0.013233770930525112, 'hitrate': 0.06425696158497192}
# time spent so far: 1.504m
# iters: 2000
# train loss: 7.3851932592391965
# valid metrics: {'users': 60367, 'recall': 0.045020746855386, 'ndcg': 0.02030191875047928, 'hitrate': 0.09346165951596071}
# time spent so far: 3.008m
# iters: 3000
# train loss: 6.931842414855957
# valid metrics: {'users': 60367, 'recall': 0.056218087322744546, 'ndcg': 0.025252948218746882, 'hitrate': 0.11761392813954644}
# time spent so far: 4.514m
# iters: 4000
# train loss: 6.542975493431092
# valid metrics: {'users': 60367, 'recall': 0.06566494773757985, 'ndcg': 0.029282526206027188, 'hitrate': 0.13669720211373765}
# time spent so far: 6.020m
# iters: 5000
# train loss: 6.187354376792908
# valid metrics: {'users': 60367, 'recall': 0.06956225495535082, 'ndcg': 0.030931959736520822, 'hitrate': 0.1449136117415144}
# time spent so far: 7.526m
# iters: 6000
# train loss: 5.912199566841125
# valid metrics: {'users': 60367, 'recall': 0.07350318595913638, 'ndcg': 0.03240776393499318, 'hitrate': 0.15210297016581908}
# time spent so far: 9.032m
# iters: 7000
# train loss: 5.684265790462494
# valid metrics: {'users': 60367, 'recall': 0.07614585569331003, 'ndcg': 0.03311193230590614, 'hitrate': 0.1574204449450859}
# time spent so far: 10.539m
# iters: 8000
# train loss: 5.477964596271515
# valid metrics: {'users': 60367, 'recall': 0.0781088151263763, 'ndcg': 0.033784944215994185, 'hitrate': 0.16111451620918713}
# time spent so far: 12.046m
# iters: 9000
# train loss: 5.3019663100242616
# valid metrics: {'users': 60367, 'recall': 0.07954946511592337, 'ndcg': 0.03395867973549404, 'hitrate': 0.1637484055858333}
# time spent so far: 13.554m
# iters: 10000
# train loss: 5.13569709777832
# valid metrics: {'users': 60367, 'recall': 0.08137976931075978, 'ndcg': 0.03457508103919855, 'hitrate': 0.1677572183477728}
# time spent so far: 15.062m
# iters: 11000
# train loss: 4.983372520446777
# valid metrics: {'users': 60367, 'recall': 0.08354639444320723, 'ndcg': 0.03539774844139105, 'hitrate': 0.17193168452962712}
# time spent so far: 16.571m
# iters: 12000
# train loss: 4.862173773765564
# valid metrics: {'users': 60367, 'recall': 0.08426121649289027, 'ndcg': 0.03571956530734318, 'hitrate': 0.1742177017244521}
# time spent so far: 18.078m
# iters: 13000
# train loss: 4.736807759284973
# valid metrics: {'users': 60367, 'recall': 0.08512424107951008, 'ndcg': 0.03610297892059085, 'hitrate': 0.17640432686732818}
# time spent so far: 19.587m
# iters: 14000
# train loss: 4.611470974445343
# valid metrics: {'users': 60367, 'recall': 0.08653175416721193, 'ndcg': 0.03644270568898953, 'hitrate': 0.17812712243444265}
# time spent so far: 21.096m
# iters: 15000
# train loss: 4.502369724035263
# valid metrics: {'users': 60367, 'recall': 0.08575639297926332, 'ndcg': 0.03597825612112205, 'hitrate': 0.17759703149071512}
# time spent so far: 22.605m
# iters: 16000
# train loss: 4.408516005039215
# valid metrics: {'users': 60367, 'recall': 0.08732940343365193, 'ndcg': 0.035957069021642925, 'hitrate': 0.17965113389765933}
# time spent so far: 24.112m
# iters: 17000
# train loss: 4.331975780010223
# valid metrics: {'users': 60367, 'recall': 0.08682444797816187, 'ndcg': 0.036251859141895756, 'hitrate': 0.17903821624397437}
# time spent so far: 25.621m
# iters: 18000
# train loss: 4.235715498208999
# valid metrics: {'users': 60367, 'recall': 0.08710034203082202, 'ndcg': 0.03631810382592223, 'hitrate': 0.18028061689333577}
# time spent so far: 27.130m
# iters: 19000
# train loss: 4.165683733940124
# valid metrics: {'users': 60367, 'recall': 0.0876691745676622, 'ndcg': 0.03648625052008401, 'hitrate': 0.1812745374128249}
# time spent so far: 28.639m
# iters: 20000
# train loss: 4.108382645845413
# valid metrics: {'users': 60367, 'recall': 0.0860018634215407, 'ndcg': 0.035538159691390195, 'hitrate': 0.17951861116172743}
# time spent so far: 30.147m

# %% [markdown]
# ## SA Quantitative evaluation

# %%
test_metrics = eval_model_on(
    data_iter=test_data,
    item_embs_fn=sa_item_embs_fn,
    user_embs_fn=sa_user_embs_fn)
print(f"test metrics: {test_metrics}")
# Out:
# test metrics: {'users': 60367, 'recall': 0.08604631125961366, 'ndcg': 0.0354178386347241, 'hitrate': 0.1791044776119403}

# %%
model_metrics['SA'] = test_metrics

# %% [markdown]
# ## SA Qualitative evaluation

# %%
eval_similar_items(sa_item_embs_fn)
# Out:
# Item title: Gone Girl
# Similar items are:
# 26.216997 Gone Girl
# 20.250338 The Husband's Secret
# 19.377922 the rosie project
# 18.961306 Where'd You Go, Bernadette: A Novel
# 18.870838 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 18.327732 Me Before You: A Novel
# 17.937778 Dark Places: A Novel
# 17.414421 What Alice Forgot
# 17.31912 The Cuckoo's Calling
# 17.267544 Hidden
#
# Item title: The Hunger Games (The Hunger Games, Book 1)
# Similar items are:
# 25.331823 The Hunger Games (The Hunger Games, Book 1)
# 22.63208 Mockingjay (The Final Book of The Hunger Games)
# 21.524817 Catching Fire (The Hunger Games, Book 2)
# 20.793644 Catching Fire (The Hunger Games, Book 2)
# 17.70578 The Call Of The Wild
# 17.592798 Abraham Lincoln: Vampire Hunter
# 17.579369 Fancy Nancy: Stellar Stargazer!
# 16.325891 Insurgent (Divergent)
# 16.270643 Saved by the Shell! (Teenage Mutant Ninja Turtles) (Pictureback(R))
# 16.105295 The Host
#
# Item title: The Book Thief
# Similar items are:
# 27.633823 The Book Thief
# 21.063713 Unbroken
# 20.127247 Sycamore Row
# 19.984964 The Husband's Secret
# 19.411621 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 19.357416 I Am the Messenger
# 19.084476 Fault in Our Stars the
# 18.834076 The Fault in Our Stars
# 18.718243 War Brides
# 18.537672 Orphan Train: A Novel
#
# Item title: Sycamore Row
# Similar items are:
# 31.562977 Sycamore Row
# 22.461025 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 22.05935 Field of Prey
# 21.834656 A Time to Kill: A Novel
# 21.774025 How the States Got Their Shapes
# 21.300064 Killing Jesus
# 21.255316 Moving Day: A Thriller
# 21.14759 Supreme Justice
# 21.02638 Twelve Years a Slave
# 20.89529 The Racketeer
#
# Item title: Mockingjay (The Final Book of The Hunger Games)
# Similar items are:
# 30.314228 Mockingjay (The Final Book of The Hunger Games)
# 24.0636 Catching Fire (The Hunger Games, Book 2)
# 23.274675 Catching Fire (The Hunger Games, Book 2)
# 22.63208 The Hunger Games (The Hunger Games, Book 1)
# 18.922958 N/A
# 18.20676 Abraham Lincoln: Vampire Hunter
# 18.14551 Allegiant (Divergent, #3)
# 17.647001 The Hunger Games Trilogy Boxed Set
# 17.390755 Divergent (Book 1) (Divergent Series)
# 17.245564 30 Pieces of Silver
#
# Item title: The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# Similar items are:
# 27.870005 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 22.53384 The Invention of Wings: A Novel
# 22.461025 Sycamore Row
# 21.916555 The Signature of All Things: A Novel
# 20.812551 All the Light We Cannot See: A Novel
# 20.587862 Orphan Train: A Novel
# 20.42057 Just One Evil Act: A Lynley Novel (Inspector Lynley)
# 20.305496 The Husband's Secret
# 19.991411 You Should Have Known
# 19.79098 Natchez Burning: A Novel (Penn Cage)
#
# Item title: Inferno
# Similar items are:
# 29.074945 Inferno
# 20.590628 Sycamore Row
# 18.998232 How the States Got Their Shapes
# 18.791374 The Quest: A Novel
# 18.25517 The Atlantis Gene: A Thriller (The Origin Mystery, Book 1)
# 18.017084 In The Company of Soldiers: A Chronicle of Combat in Iraq
# 17.719778 The Wolves of Midwinter: The Wolf Gift Chronicles
# 17.675375 Command Authority (Jack Ryan)
# 17.616007 The Hit (Will Robie Series)
# 17.61372 The Accidental Species: Misunderstandings of Human Evolution
#
# Item title: Allegiant (Divergent, #3)
# Similar items are:
# 28.049257 Allegiant (Divergent, #3)
# 23.162962 Insurgent (Divergent)
# 23.010853 The Fault in Our Stars
# 22.212019 Divergent (Book 1) (Divergent Series)
# 21.37079 Divergent (Turtleback School &amp; Library Binding Edition) (Divergent Trilogy)
# 20.855825 Divergent Series Complete Box Set
# 20.168545 World After (Penryn &amp; the End of Days, Book 2)
# 20.110205 Divergent
# 19.72005 The One (The Selection)
# 19.592524 Looking for Alaska
#
# Item title: Hopeless
# Similar items are:
# 23.870733 Hopeless
# 18.324543 Finding Cinderella: A Novella
# 17.59533 Out of Breath (Breathing)
# 17.508553 The Edge of Never
# 17.268301 Hidden
# 17.267836 Making Faces
# 17.223143 Wait For Me: Romantic Suspense
# 17.139889 Losing Hope Signed Limited Edition: A Novel
# 16.98983 Jane's Melody
# 16.964058 The Coincidence of Callie &amp; Kayden

# %% [markdown]
# Next, I evaluate the recommendations for the users and how the attention affects the user embedding in the Self-Attention model.

# %%
def eval_user_recommendations_with_attention():
  item_embs = sa_item_embs_fn()
  gpu_index = build_item_index(item_embs)
  
  item_att_w, user_embs, = sess_sa.run([model_sa.item_att_w, model_sa.user_eb], feed_dict={
      model_sa.mid_his_batch_ph: eval_hist_item_list,
      model_sa.mask: eval_hist_mask_list,
  })
  item_att_w = np.squeeze(item_att_w, axis=1)
  user_embs = np.squeeze(user_embs, axis=1)
  
  D, I = gpu_index.search(user_embs, 10)
  for att, hist_item_list, hist_mask_list, dd, ii in zip(
      item_att_w, eval_hist_item_list, eval_hist_mask_list, D, I):
    print('For the user with the following history the embedding is formed as:')
    for a, item, mask in zip(att, hist_item_list, hist_mask_list):
      if mask == 0.0:
        break
      print(f"[attention={a:.6f}]", item_id_to_title[item])
    print("Recommendations are are:")
    for d, i in zip(dd, ii):
      print(d, item_id_to_title[i])
    print()
      
eval_user_recommendations_with_attention()
# Out:
# For the user with the following history the embedding is formed as:
# [attention=0.183582] Gone Girl
# [attention=0.268127] The Dog Stars (Vintage Contemporaries)
# [attention=0.240535] Fahrenheit 451 Low Price CD
# [attention=0.307756] Ready Player One
# Recommendations are are:
# 16.457071 Ready Player One
# 14.277361 The Dog Stars (Vintage Contemporaries)
# 14.076849 The Martian: A Novel
# 13.689842 The Ocean at the End of the Lane: A Novel
# 13.121575 Wool - Omnibus Edition
# 12.939957 World War Z: An Oral History of the Zombie War
# 12.834494 The Casual Vacancy
# 12.224459 11/22/63 (Thorndike Press Large Print Core Series)
# 12.196857 Gone Girl
# 12.15394 The Road
#
# For the user with the following history the embedding is formed as:
# [attention=0.025527] One Last Thing Before I Go: A Novel
# [attention=0.021458] Sacre Bleu: A Comedy d'Art
# [attention=0.016593] Fahrenheit 451 Low Price CD
# [attention=0.016550] The Time Keeper
# [attention=0.034473] How to Talk to a Widower
# [attention=0.012166] The Adventures of Sherlock Holmes (Dover Thrift Editions)
# [attention=0.024020] The Casual Vacancy
# [attention=0.036090] Brain on Fire: My Month of Madness
# [attention=0.028707] Unbroken
# [attention=0.065440] The Martian Chronicles (Harper Perennial Modern Classics)
# [attention=0.064914] The Twelve Tribes of Hattie (Vintage)
# [attention=0.059364] The Round House
# [attention=0.090057] When She Woke
# [attention=0.076108] Mr. Penumbra's 24-Hour Bookstore: A Novel
# [attention=0.076968] The Elegance of the Hedgehog
# [attention=0.054513] The Bungalow: A Novel
# [attention=0.075252] The Language of Flowers
# [attention=0.008885] Juliet, Naked
# [attention=0.117472] Sharp Objects: A Novel
# [attention=0.095444] Tell the Wolves I'm Home: A Novel
# Recommendations are are:
# 11.701158 Where'd You Go, Bernadette: A Novel
# 11.290449 The Goldfinch: A Novel (Pulitzer Prize for Fiction)
# 11.06733 Gone Girl
# 11.055301 The Light Between Oceans
# 10.726456 The Dinner
# 10.546769 Me Before You: A Novel
# 10.535067 Life After Life: A Novel
# 10.521027 The Husband's Secret
# 10.386125 Mr. Penumbra's 24-Hour Bookstore: A Novel
# 10.356586 The Language of Flowers
#
# For the user with the following history the embedding is formed as:
# [attention=0.087851] Dr. Atkins' New Diet Revolution
# [attention=0.023329] N/A
# [attention=0.313553] Eifelheim
# [attention=0.575266] Charlotte Collins: A Continuation of Jane Austen's Pride and Prejudice
# Recommendations are are:
# 18.227367 Charlotte Collins: A Continuation of Jane Austen's Pride and Prejudice
# 11.086231 Pemberley to Waterloo: Georgiana Darcy's Diary, Volume 2
# 10.339162 His Good Opinion: A Mr. Darcy Novel
# 9.883035 N/A
# 9.13211 Wars of Blood and Faith: The Conflicts That Will Shape the 21st Century
# 9.034669 Finding Her Way (Wildflowers) (Volume 1)
# 8.990581 N/A
# 8.743297 Tanglewood Plantation
# 8.732582 Common Stocks and Uncommon Profits and Other Writings
# 8.677472 Flatlander
#
# For the user with the following history the embedding is formed as:
# [attention=0.023403] N/A
# [attention=0.018853] Deeper
# [attention=0.003607] Beyond Me: Sex on the Beach
# [attention=0.046548] Deadland's Harvest (Deadland Saga) (Volume 2)
# [attention=0.034892] Against All Odds
# [attention=0.039768] N/A
# [attention=0.043270] Frenched (Volume 1)
# [attention=0.031941] Falling Into You
# [attention=0.041642] Bend: The Complete Banned Anthology
# [attention=0.043033] Beg Tease Submit - Sequence One (Songs of Submission)
# [attention=0.054702] N/A
# [attention=0.063133] Sing (Songs of Submission) (Volume 7)
# [attention=0.057361] N/A
# [attention=0.050468] Taking Chances
# [attention=0.025479] N/A
# [attention=0.076705] Spin (Songs of Corruption) (Volume 1)
# [attention=0.066414] Chasing Beautiful (Chasing Series Book)
# [attention=0.066217] Good (Too Good)
# [attention=0.081583] Better (Too Good)
# [attention=0.130983] Beautiful Broken Rules
# Recommendations are are:
# 14.427447 Sing (Songs of Submission) (Volume 7)
# 13.111571 Beg (Los Angeles Nights)
# 12.950358 Spin (Songs of Corruption) (Volume 1)
# 12.829009 Bend: The Complete Banned Anthology
# 12.53997 N/A
# 12.0431185 Reviving Izabel (In the Company of Killers) (Volume 2)
# 11.239221 Beg Tease Submit - Sequence One (Songs of Submission)
# 11.122993 Night Owl (The Night Owl Trilogy)
# 10.970984 Forever With You (Fixed) (Volume 3)
# 10.890637 Beautifully Awake
#
# For the user with the following history the embedding is formed as:
# [attention=0.208761] Pickle-Chiffon Pie
# [attention=0.254487] Insane City
# [attention=0.000001] The Brilliant Disaster: JFK, Castro, and America's Doomed Invasion of Cuba's Bay of Pigs
# [attention=0.306944] Forrest Gump (Movie Tie in)
# [attention=0.229808] Younger Next Year: A Guide to Living Like 50 Until You're 80 and Beyond
# Recommendations are are:
# 9.50091 Insane City
# 8.065391 Power of Habit: Why We Do What We Do, and How to Change
# 7.8782825 Younger Next Year: A Guide to Living Like 50 Until You're 80 and Beyond
# 7.8743963 The House of God: The Classic Novel of Life and Death in an American Hospital
# 7.7448506 The Big Short: Inside the Doomsday Machine
# 7.43543 Portrait of a Killer: Jack the Ripper--Case Closed
# 7.3992023 Deja Dead (Temperance Brennan Novels)
# 7.206353 Mary Ann in Autumn: A Tales of the City Novel
# 7.1964602 Free: The Future of a Radical Price
# 7.1834755 Raising Steam (Discworld)
#
# For the user with the following history the embedding is formed as:
# [attention=0.048964] N/A
# [attention=0.165296] N/A
# [attention=0.294089] N/A
# [attention=0.491650] N/A
# Recommendations are are:
# 9.867428 N/A
# 9.50802 N/A
# 9.455842 Connelly's Flame
# 9.237434 N/A
# 9.151393 Romancing Sal Gabrini
# 9.147615 N/A
# 9.093035 N/A
# 9.089788 Tale of the Tigers
# 9.088105 N/A
# 8.9833765 The Book of Joshua II - Believe (Gems and Gents) (Volume 3)
#
# For the user with the following history the embedding is formed as:
# [attention=0.254758] Baby Catcher: Chronicles of a Modern Midwife
# [attention=0.001369] Witches, Midwives, and Nurses: A History of Women Healers (Contemporary Classics)
# [attention=0.266493] The Belly Book: A Nine-Month Journal for You and Your Growing Belly (Potter Style)
# [attention=0.254612] Spoon
# [attention=0.222768] Chopsticks
# Recommendations are are:
# 10.570077 Baby Catcher: Chronicles of a Modern Midwife
# 10.431854 The Girlfriends' Guide to Pregnancy
# 10.341469 The Belly Book: A Nine-Month Journal for You and Your Growing Belly (Potter Style)
# 9.401771 Spoon
# 9.303897 The Pigeon Has Feelings, Too!
# 9.152266 The Happiest Baby on the Block
# 8.77644 Steam Train, Dream Train
# 8.475271 Goodnight, Goodnight, Construction Site Matching Game
# 8.335212 I Just Want to Pee Alone
# 8.326778 A Smart Girl's Guide to Knowing What to Say (American Girl)
#
# For the user with the following history the embedding is formed as:
# [attention=0.085951] A Sea of Troubles (John Pearce 9)
# [attention=0.146261] Little Dorrit (Penguin Classics)
# [attention=0.112824] The Cloud Collector's Handbook
# [attention=0.253647] Buddhism for Beginners
# [attention=0.045596] The Shadow of the Eagle: #13 A Nathaniel Drinkwater Novel (Mariners Library Fiction Classic)
# [attention=0.174324] Overnight Colon and Liver Cleanse &amp; Detox: Get Your Energy, Stamina and Mental Clarity Back in 11 days and Lose Weight Fast in the Process!
# [attention=0.181398] Ben-Hur (Oxford World's Classics)
# Recommendations are are:
# 8.905844 Buddhism for Beginners
# 6.0388265 Gunny's Rules: How to Get Squared Away Like a Marine
# 5.566119 The Cross in the Closet
# 5.4806724 HCSB Study Bible, Black Deluxe Leather
# 5.1274743 Reflexive Fire
# 5.0942583 The Last Days of the Incas
# 4.971188 Paranormal State: My Journey into the Unknown
# 4.929 Israel Strikes
# 4.92588 Paint Like Monet (Masterclass)
# 4.891984 The Cloud Collector's Handbook
#
# For the user with the following history the embedding is formed as:
# [attention=0.508988] A Singular Woman: The Untold Story of Barack Obama's Mother
# [attention=0.490223] N/A
# [attention=0.000003] Agatha Raisin and the Fairies of Fryfam (Agatha Raisin Mysteries, No. 10)
# [attention=0.000786] The Walkers of Dembley (Agatha Raisin Mysteries)
# Recommendations are are:
# 11.005499 A Singular Woman: The Untold Story of Barack Obama's Mother
# 8.248645 The Girl Who Circumnavigated Fairyland in a Ship of Her Own Making
# 8.2362175 Pukka's Promise: The Quest for Longer-Lived Dogs
# 7.8470964 Beautiful No-Mow Yards: 50 Amazing Lawn Alternatives
# 7.613323 The America's Test Kitchen Cooking School Cookbook
# 7.6123753 Before You Suffocate Your Own Fool Self
# 7.5637136 The Feed Zone Cookbook: Fast and Flavorful Food for Athletes
# 7.530933 The Man Who Killed Kennedy: The Case Against LBJ
# 7.5265675 The Jesus Discovery: The Resurrection Tomb that Reveals the Birth of Christianity
# 7.4406247 Mary's Mosaic: The CIA Conspiracy to Murder John F. Kennedy, Mary Pinchot Meyer, and Their Vision for World Peace
#
# For the user with the following history the embedding is formed as:
# [attention=0.174713] N/A
# [attention=0.125583] N/A
# [attention=0.058541] Amish Faith: An Amish Christian Romance
# [attention=0.260746] Fields of Corn: The Amish of Lancaster
# [attention=0.058788] Hills of Wheat: The Amish of Lancaster Series
# [attention=0.147579] Ozark Sweetheart (Heartsong Presents)
# [attention=0.174050] N/A
# Recommendations are are:
# 9.614693 Fields of Corn: The Amish of Lancaster
# 8.803418 Where the Heart Leads (Waiting for Summer's Return Series #2)
# 8.795772 N/A
# 8.214093 Hills of Wheat: The Amish of Lancaster Series
# 7.9858484 A Promise for Spring
# 7.7133245 N/A
# 7.688294 N/A
# 7.6238785 Katie's Redemption (Brides of Amish Country, Book 1)
# 7.558024 N/A
# 7.554883 A Christmas Gift for Rebecca

# %% [markdown]
# # 5. Results

# %% [markdown]
# I present the quantitative results of all models together.

# %%
for model, metrics in model_metrics.items():
  print(model)
  print(metrics)
# Out:
# BPR
# {'users': 60367, 'recall': 0.0793839708971102, 'ndcg': 0.030340466471052048, 'hitrate': 0.157287922209154}
# DNN
# {'users': 60367, 'recall': 0.06991044218893151, 'ndcg': 0.03219544022900266, 'hitrate': 0.15322941342124008}
# SA
# {'users': 60367, 'recall': 0.08604631125961366, 'ndcg': 0.0354178386347241, 'hitrate': 0.1791044776119403}
